# %%
import datetime
import ib_insync
import pandas as pd
import logging
import numpy as np
import time
import os

ib_insync.util.startLoop()

# %%
from ib_insync import*

# %%
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(name)s - %(levelname)s - %(message)s')
logger = logging.getLogger("ib_downloader")
handler = logging.FileHandler('ib_downloader_1min_bar.log')
formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
handler.setFormatter(formatter)
logger.addHandler(handler)

# %%
class IbDownloadTimer(object):
    def __init__(self):
        self._t_array: np.ndarray = np.array([])
    
    def reset(self):
        """
        Reset timer
        """
        self._t_array = np.array([])
    
    def add_new_event(self):
        """
        Add a new download event into the time array. IB
        only allows 60 requests every 10 minutes. Therefore
        set a time buffer to make sure no more than 60 requests
        are made each 10 minutes.
        """
        # Remove event that is 10 minutes ago
        time_diff = datetime.datetime.now() - self._t_array
        self._t_array = self._t_array[time_diff <= datetime.timedelta(minutes=10)]
        
        # If more than 55 requests made in this ten minutes
        if len(self._t_array) > 40:
            logger.info("Waiting until IB 60/10 minutes time buffer clears")
            while len(self._t_array) > 40:
                # wait sometime
                time.sleep(2)
                # delete all time stamps 10 minutes ago
                time_diff = datetime.datetime.now() - self._t_array
                self._t_array = self._t_array[time_diff <= datetime.timedelta(minutes=10)]

        self._t_array = np.append(self._t_array, datetime.datetime.now())

    @property
    def t_array(self):
        return self._t_array

# %%
ib = ib_insync.IB()
ib.connect('127.0.0.1', 7497, clientId=1)
# Out:
# 2020-03-05 07:58:46,480 - ib_insync.client - INFO - Connecting to 127.0.0.1:7497 with clientId 1...
# 2020-03-05 07:58:46,482 - ib_insync.client - INFO - Connected
# 2020-03-05 07:58:46,595 - ib_insync.client - INFO - Logged on to server version 142
# 2020-03-05 07:58:46,649 - ib_insync.wrapper - INFO - Warning 2104, reqId -1: Market data farm connection is OK:usfarm.nj
# 2020-03-05 07:58:46,650 - ib_insync.wrapper - INFO - Warning 2104, reqId -1: Market data farm connection is OK:cashfarm
# 2020-03-05 07:58:46,651 - ib_insync.wrapper - INFO - Warning 2104, reqId -1: Market data farm connection is OK:usfarm
# 2020-03-05 07:58:46,651 - ib_insync.wrapper - INFO - Warning 2106, reqId -1: HMDS data farm connection is OK:ushmds
# 2020-03-05 07:58:46,652 - ib_insync.client - INFO - API connection ready
# 2020-03-05 07:58:46,830 - ib_insync.ib - INFO - Synchronization complete
# <IB connected to 127.0.0.1:7497 clientId=1>

# %%
class IbDataDownloader(object):
    def __init__(self):
        self._timer: IbDownloadTimer = IbDownloadTimer()   
    @property
    def t_array(self):
        return self._timer.t_array
    
    def reset_timer(self):
        self._timer.reset()
        
    def load_symbols_csv(self,
                         csv_path: str):
        self._symbols_df = pd.read_csv(csv_path)
        
    def get_all_symbols_lifetime_data(self,
                                      symbols_list: list,
                                      exchanges_list: list,
                                      output_folder: str,
                                      duration_str='10 D',
                                      bar_size='1 min',
                                      what_to_Show='TRADES',
                                      useRTH=True,
                                      formatDate=1):
        """
        Given a list of symbols and corresponding exchanges, download data and save to local csv files.
        """
        for ix, symbol in enumerate(symbols_list):
            logger.info("Processing symbol: {}".format(symbol))
            exchange = exchanges_list[ix]
            sub_contracts: list = self.get_sub_contracts(symbol, exchange)
            


            for contract in sub_contracts:
                download_success = False
                while not download_success:
                    try:
                        df = self.get_one_symbol_lifetime_data(
                             contract=contract,
                             duration_str=duration_str,
                             bar_size=bar_size,
                             whatToShow=what_to_Show,
                             useRTH=useRTH,
                             formatDate=formatDate
                        )
                        file_name = contract.localSymbol + "_" + contract.lastTradeDateOrContractMonth + ".csv"
                        data_path = os.path.join(output_folder, file_name)
                        # Make sure the data returned is not a none object
                        if type(df) == pd.core.frame.DataFrame:
                            if not df.empty:
                                df.to_csv(data_path, index=False)
                        download_success = True
                    except:
                        time.sleep(30)
                        ib.connect('127.0.0.1', 7497, clientId=1)

        
    def get_sub_contracts(self,
                          symbol: str,
                          exchange: str):
        """
        Given an symbol and exchange, return all possible sub contracts in a list.
        """
        contract_details = ib.reqContractDetails(Future(symbol=symbol, includeExpired=True))
        time.sleep(10)
        if len(contract_details) != 0:
            cd_frame = ib_insync.util.df([cd.contract for cd in contract_details])
            frame = cd_frame[cd_frame.loc[:,"exchange"] == exchange]
            def datetime_transform(x):
                return datetime.datetime.strptime(x, '%Y%m%d')
            frame.loc[:, "LastdayDatetime"] = frame.loc[:, "lastTradeDateOrContractMonth"].apply(datetime_transform)
            latest_last_day = datetime.datetime.now() + datetime.timedelta(days=120)
            frame = frame[frame.loc[:, "LastdayDatetime"] < latest_last_day]
            sub_contracts_list = []
            for index, row in frame.iterrows():
                contract = Future(localSymbol=row.loc["localSymbol"],
                                  exchange=row.loc["exchange"],
                                  lastTradeDateOrContractMonth=row.loc["lastTradeDateOrContractMonth"],
                                  includeExpired=True)

                sub_contracts_list.append(contract)
            return sub_contracts_list
        else:
            return []

        
    def get_one_symbol_lifetime_data(self,
                                     contract: ib_insync.Contract,
                                     duration_str='10 D',
                                     bar_size='1 min',
                                     whatToShow='TRADES',
                                     useRTH=True,
                                     formatDate=1):
        """
        Get one contract data in its entire lifetime. Return a pandas dataframe.
        """
        # Make sure the contract is good and unique
        if len(ib.qualifyContracts(contract)) != 1:
            logger.error("incorrect contract: {}".format(str(contract)))
            logger.info("sleep 10 sec")
            time.sleep(10)
            return
        logger.info("sleep 10 sec")
        time.sleep(10)
        logger.info("downloading symbol: {}".format(str(contract)))
        # current time string for end data time is empty string
        dt = ""
        barsList = []
        while True:
            self._timer.add_new_event()
            logger.info("Start downloading data to date: {}".format(dt))
            start_time = time.time()
            bars = ib.reqHistoricalData(
                contract,
                endDateTime=dt,
                durationStr=duration_str,
                barSizeSetting=bar_size,
                whatToShow=whatToShow,
                useRTH=useRTH,
                formatDate=formatDate)


            end_time = time.time()


            # If no bars received or received bar data is always the last day, break
            if not bars:
                logger.info("sleep 30 sec")
                time.sleep(30)
                break
            elif len(bars) < 2:
                logger.info("sleep 30 sec")
                time.sleep(30)
                break
            else:
                barsList.append(bars)
                dt = bars[0].date
                logger.info("downloading using time: {} sec".format(round(end_time - start_time, 2)))
                logger.info("Finish downloading data to date: {}".format(dt))

                # Sleep some time before next request due to IB does not like frequent requests
                logger.info("sleep 30 sec")
                time.sleep(30)
            
        allBars = [b for bars in reversed(barsList) for b in bars]
        df = ib_insync.util.df(allBars)
        logger.info("Finish downloading all data for symbol: {}".format(str(contract)))
        return df

# %%
downloader = IbDataDownloader()

# %% [markdown]
# ```python
# # single simble download
# contract = Future(localSymbol="CLM0", exchange = "NYMEX")
# df = downloader.get_one_symbol_lifetime_data(contract,
#                                              duration_str='120 D',
#                                              bar_size='1 day',
#                                              whatToShow='TRADES',
#                                              useRTH=True,
#                                              formatDate=1)
# ```

# %%
output_folder = r"C:\nutstore\Nutstore\future_1min_bars"

# %%
symbol_df_path = r"C:\nutstore\Nutstore\my_interested_symbols.csv"
symbol_df = pd.read_csv(symbol_df_path)

# %%
symbol_df
# Out:
#    Symbol                           Name Exchange  Start Date First Contract  \
# 0      AD      CME Australian Dollar AUD      CME   3/16/1987          H1987
# 1      BO               CBOT Soybean Oil     CBOT   9/20/1961          U1961
# 2      BP          CME British Pound GBP      CME   9/15/1975          U1975
# 3       C                      CBOT Corn     CBOT   3/22/1960          H1960
# 4      CD        CME Canadian Dollar CAD      CME   6/14/1977          M1977
# 5      CL            NYMEX WTI Crude Oil    NYMEX   5/18/1983          M1983
# 6      DA             CME Class III Milk      CME  12/31/1997          Z1997
# 7      EC                    CME Euro FX      CME   3/15/1999          H1999
# 8      ED                 CME Eurodollar      CME   3/15/1982          H1982
# 9      ES       CME S&P 500 Index E-Mini      CME  12/18/1997          Z1997
# 10     FF      CBOT 30-day Federal Funds     CBOT   12/1/1988          X1988
# 11     FV   CBOT 5-year US Treasury Note     CBOT   6/21/1988          M1988
# 12     GC                     NYMEX Gold    NYMEX   2/25/1975          G1975
# 13     HG                   COMEX Copper    COMEX  12/29/1959          Z1959
# 14     HO              NYMEX Heating Oil    NYMEX  12/28/1979          F1980
# 15     JY           CME Japanese Yen JPY      CME   3/11/1977          H1977
# 16     KW          CME Kansas City Wheat      CME   9/21/1976          U1976
# 17     LB       CME Random Length Lumber      CME   9/14/1973          U1973
# 18     LC                CME Live Cattle      CME   4/20/1965          J1965
# 19     LN                  CME Lean Hogs      CME   2/20/1970          G1970
# 20     MD       CME S&P 400 Midcap Index      CME   3/19/1992          H1992
# 21     MP               CME Mexican Peso      CME   6/19/1995          M1995
# 22     NE     CME New Zealand Dollar NZD      CME  12/13/2004          Z2004
# 23     NG              NYMEX Natural Gas    NYMEX   5/22/1990          M1990
# 24     NK                 CME Nikkei 225      CME  12/13/1990          Z1990
# 25     NQ      CME NASDAQ 100 Index Mini      CME   9/17/1999          U1999
# 26      O                      CBOT Oats     CBOT   3/19/1970          H1970
# 27     PA                NYMEX Palladium    NYMEX   3/14/1977          H1977
# 28     PL                 NYMEX Platinum    NYMEX   1/14/1970          F1970
# 29     RB                 NYMEX Gasoline    NYMEX  12/30/2005          F2006
# 30     RR                CBOT Rough Rice     CBOT   9/21/1988          U1988
# 31    RS1    CME Russell 1000 Index Mini      CME   5/11/2007       RS1U2007
# 32    RTY    CME Russell 2000 Index Mini      CME   9/15/2006       RTYH2007
# 33      S                  CBOT Soybeans     CBOT   1/21/1970          F1970
# 34     SF            CME Swiss Franc CHF      CME   9/15/1975          U1975
# 35     SI                   NYMEX Silver    NYMEX   3/30/1964          H1964
# 36     SM              CBOT Soybean Meal     CBOT   3/19/1964          H1964
# 37     SP              CME S&P 500 Index      CME   6/17/1982          M1982
# 38     TU   CBOT 2-year US Treasury Note     CBOT   9/19/1990          U1990
# 39     TY  CBOT 10-year US Treasury Note     CBOT   6/21/1982          M1982
# 40     US  CBOT 30-year US Treasury Bond     CBOT  12/20/1977          Z1977
# 41     VX               CBOE VIX Futures     CBOE  12/19/2007          Z2007
# 42      W                     CBOT Wheat     CBOT  12/21/1959          Z1959
# 43     YM           CME E-mini Dow Jones      CME  12/18/1997          Z1997
#
#           Months                                          Tick Size  \
# 0           HMUZ  $.0001 per Australian dollar increments ($10.0...
# 1       FHKNQUVZ  1/100 of a cent ($0.0001) per pound ($6.00 per...
# 2           HMUZ  $.0001 per British pound increments ($6.25/con...
# 3          HKNUZ   1/4 of one cent per bushel ($12.50 per contract)
# 4           HMUZ  $.0001 per Canadian dollar increments ($10.00/...
# 5   FGHJKMNQUVXZ                                    $0.01per barrel
# 6   FGHJKMNQUVXZ              $0.01 per cwt (= $20.00 per contract)
# 7           HMUZ  $.0001 per euro increments ($12.50/contract). ...
# 8           HMUZ  Nearest expiring contract month: One quarter o...
# 9           HMUZ                           0.25 index points=$12.50
# 10  FGHJKMNQUVXZ  Nearest expiring contract month: One-quarter o...
# 11          HMUZ  One-quarter of one thirty-second (1/32) of one...
# 12        GJMQVZ                               $0.10 per troy ounce
# 13        FHKNUZ                                  $0.0005 per pound
# 14  FGHJKMNQUVXZ                                 $0.0001 per gallon
# 15          HMUZ  $.000001 per Japanese yen increments ($12.50/c...
# 16         HKNUZ          1/4 cent per bushel ($12.50 per contract)
# 17        FHKNUX                    $.10 per mbf ($11 per contract)
# 18        GJMQVZ              $.00025 per pound (=$10 per contract)
# 19       GJMNQVZ               $.00025 per pound ($10 per contract)
# 20          HMUZ                                        0.10=$10.00
# 21          HMUZ  $.00001 per Mexican peso increments ($5.00/con...
# 22          HMUZ  $.0001 per New Zealand dollar increments ($10....
# 23  FGHJKMNQUVXZ                                   $0.001 per MMBtu
# 24          HMUZ                           5.00 index points=$25.00
# 25          HMUZ                            0.25 index points=$5.00
# 26         HKNUZ    1/4 of one cent per bushel ($12.50 per contract
# 27          HMUZ                               $0.05 per troy ounce
# 28          FJNV                               $0.10 per troy ounce
# 29  FGHJKMNQUVXZ                                 $0.0001 per gallon
# 30        FHKNUX   1/2 cent per hundredweight ($10.00 per contract)
# 31          HMUZ                Index points, to two decimal places
# 32          HMUZ                Index points, to two decimal places
# 33       FHKNQUX   1/4 of one cent per bushel ($12.50 per contract)
# 34          HMUZ  $.0001 per Swiss Franc increments ($12.50/cont...
# 35        FHKNUZ  Outright transactions including EFP: $0.005 pe...
# 36      FHKNQUVZ       10 cents per short ton ($10.00 per contract)
# 37          HMUZ                              0.10 index points=$25
# 38          HMUZ  One-quarter of one thirty-second (1/32) of one...
# 39          HMUZ  One-half of one thirty-second (1/32) of one po...
# 40          HMUZ  One thirty-second (1/32) of one point ($31.25)...
# 41   FHJKMNQUVXZ          0.05 points, equal to $50.00 per contract
# 42         HKNUZ   1/4 of one cent per bushel ($12.50 per contract)
# 43          HMUZ                            1.00 index points=$5.00
#
#                                          Pricing Unit  \
# 0         US dollars and cents per Australian dollars
# 1                                     Cents per pound
# 2                                US dollars and cents
# 3                                    Cents per bushel
# 4                                US dollars and cents
# 5                   U.S. Dollars and Cents per barrel
# 6                      Cents per hundredweight (cwt.)
# 7                                US dollars and cents
# 8   Quoted in IMM Three-Month LIBOR index points o...
# 9                                        Index Points
# 10  100 minus the average daily Fed Funds overnigh...
# 11  Points ($1,000) and quarters of 1/32 of a poin...
# 12              U.S. Dollars and Cents per troy ounce
# 13                               U.S. Cents per pound
# 14                  U.S. dollars and cents per gallon
# 15                               US dollars and cents
# 16                 Cents and quarter cents per bushel
# 17                 Dollars per 1,000 board feet (mbf)
# 18                                    Cents per pound
# 19                                    Cents per pound
# 20                                       Index Points
# 21                               US Dollars and cents
# 22        US dollars and cents per New Zealand Dollar
# 23                  U.S. dollars and cents per mmBtu.
# 24                                       Index Points
# 25                                       Index Points
# 26                                US cents per bushel
# 27                US dollars and cents per troy ounce
# 28                   dollars and Cents per troy ounce
# 29                 U.S. dollars and cents per gallon.
# 30                         US cents per hundredweight
# 31                                    10 Index points
# 32                                    10 Index points
# 33                                   Cents per bushel
# 34               US dollars and cents per Swiss Franc
# 35                          U.S. Cents per troy ounce
# 36                    Dollars and Cents per short ton
# 37                                       Index Points
# 38  Points ($2,000) and quarters of 1/32 of a poin...
# 39  Points ($1,000) and halves of 1/32 of a point....
# 40  Points ($1,000) and 1/32 of a point. For examp...
# 41                                       Index Points
# 42                                   Cents per bushel
# 43                                       Index points
#
#                                           Deliverable  Big Point Value
# 0                          100,000 Australian dollars         100000.0
# 1   Crude soybean oil meeting exchange-approved gr...            600.0
# 2                               62,500 British pounds          62500.0
# 3   #2 Yellow at contract Price, #1 Yellow at a 1....             50.0
# 4                            100,000 Canadian dollars         100000.0
# 5   Delivery shall be made free-on-board (F.O.B.) ...           1000.0
# 6                                      Class III Milk              NaN
# 7                None, this contract is cash settled.         125000.0
# 8                 None, this contract is cash settled           2500.0
# 9                 None, this contract is cash settled             50.0
# 10  Expiring contracts are cash settled against th...           4167.0
# 11  U.S. Treasury notes with an original term to m...           1000.0
# 12  Gold delivered under this contract shall assay...            100.0
# 13                                      25,000 pounds          25000.0
# 14  The oil delivered shall be a pure hydrocarbon ...          42000.0
# 15                            12,500,000 Japanese yen             12.5
# 16  No. 2 at contract price with a maximum of 10 I...             50.0
# 17    2-inch by 4-inch nominal lumber, 8-20 feet long              NaN
# 18  55% Choice, 45% Select, Yield Grade 3 live ste...            400.0
# 19                    Hog (barrow and gilt) carcasses            400.0
# 20               None, this contract is cash settled.            500.0
# 21                              500,000 Mexican pesos              NaN
# 22                        100,000 New Zealand Dollars         100000.0
# 23  Natural Gas meeting the specifications set for...          10000.0
# 24               None, this contract is cash settled.              5.0
# 25              None, this contract is cash settlted.             20.0
# 26  No. 2 Heavy and No. 1 at par. No. 1 Extra Heav...              NaN
# 27         Palladium that is a minimum of 99.95% pure            100.0
# 28          Platinum that is a minimum of 99.95% pure             50.0
# 29  hydrocarbon oil free from alkali, mineral acid...          42000.0
# 30  U.S. No. 2 or better long grain rough rice wit...              NaN
# 31  $100 times the Index Deliverable Good: Cash se...              NaN
# 32  Cash settlement to a special opening calculati...              NaN
# 33  #2 Yellow at contract price, #1 Yellow at a 6 ...             50.0
# 34                               125,000 Swiss Francs         125000.0
# 35  Silver delivered under this contract shall ass...           5000.0
# 36  48% Protein Soybean Meal, meeting the requirem...            100.0
# 37               None, this contract is cash settled.            250.0
# 38  .S. Treasury notes with an original term to ma...           2000.0
# 39  U.S. Treasury notes with a remaining term to m...           1000.0
# 40  U.S. Treasury bonds that, if callable, are not...           1000.0
# 41                None, this contract is cash settled              NaN
# 42  #2 Soft Red Winter at contract price, #1 Soft ...             50.0
# 43                 None this contract is cash settled              NaN

# %%
symbols_list = symbol_df["Symbol"].tolist()[35:]
exchanges_list = symbol_df["Exchange"].tolist()[35:]

# %%
downloader.get_all_symbols_lifetime_data(symbols_list=symbols_list,
                                         exchanges_list=exchanges_list,
                                         output_folder=output_folder,
                                         duration_str='10 D',
                                         bar_size='1 min',
                                         what_to_Show='TRADES',
                                         useRTH=True,
                                         formatDate=1)
